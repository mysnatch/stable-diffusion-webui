# %%
# !git clone https://github.com/vilimus/stable-diffusion-webui
# %cd stable-diffusion-webui
# Out:
# Cloning into 'stable-diffusion-webui'...
# remote: Enumerating objects: 5936, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 5936 (delta 6), reused 3 (delta 1), pack-reused 5920
# Receiving objects: 100% (5936/5936), 21.47 MiB | 17.42 MiB/s, done.
# Resolving deltas: 100% (4177/4177), done.
# /content/stable-diffusion-webui

# %%
from google.colab import drive
drive.mount("/content/gdrive/")
# Out:
# Mounted at /content/gdrive/

# %%
# !cp /content/gdrive/MyDrive/novelaileak/model.ckpt /content/stable-diffusion-webui/models/Stable-diffusion/model.ckpt
# !cp /content/gdrive/MyDrive/novelaileak/config.yaml /content/stable-diffusion-webui/models/Stable-diffusion/config.yaml
# !cp /content/gdrive/MyDrive/novelaileak/animevae.pt /content/stable-diffusion-webui/models/Stable-diffusion/anime.vae.pt
# Out:
# cp: cannot stat '/content/gdrive/MyDrive/novelaileak/anime.vaept': No such file or directory

# %%
# !COMMANDLINE_ARGS="--share --gradio-debug" REQS_FILE="requirements.txt" python launch.py
# Out:
# Python 3.7.14 (default, Sep  8 2022, 00:06:44)
# [GCC 7.5.0]
# Commit hash: 3d96753e9e009506ab2696cd0985b5fab963cf4e
# Installing gfpgan
# Installing clip
# Cloning Stable Diffusion into repositories/stable-diffusion...
# Cloning Taming Transformers into repositories/taming-transformers...
# Cloning K-diffusion into repositories/k-diffusion...
# Cloning CodeFormer into repositories/CodeFormer...
# Cloning BLIP into repositories/BLIP...
# Installing requirements for CodeFormer
# Installing requirements for Web UI
# Launching Web UI with arguments: --share --gradio-debug
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# Downloading: 100% 939k/939k [00:01<00:00, 704kB/s]
# Downloading: 100% 512k/512k [00:01<00:00, 469kB/s]
# ...
